# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img = plt.imread("Images\Flower.png")


plt.subplot(131)
plt.imshow(img)

plt.subplot(132)
Gauss1 = cv2.GaussianBlur(img, (5,5), 15)
plt.imshow(Gauss1)
plt.subplot(133)

Gauss2 = cv2.GaussianBlur(img, (5,5), 55)
plt.imshow(Gauss2)
plt.show()
